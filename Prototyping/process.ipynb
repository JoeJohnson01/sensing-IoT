# %%
from processClass import dataProcessor
import pandas as pd

# %%
calibrationData = pd.read_csv('c1.csv')

# %%
p = dataProcessor()

# %%
p.createCalibrationData(calibrationData)
# Out:
# c:\Users\01joh\OneDrive\Desktop\IoT\Prototyping\processClass.py:106: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   rotation = R.align_vectors([desired_orientation], [
# C:\Users\01joh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# C:\Users\01joh\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\scipy\interpolate\_fitpack2.py:298: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# ...

# %%
p.visualiseCalibrationSet()

# %%
# For one sensors data
exerciseData = [pd.read_csv('t1.csv')]
p.processSet(exerciseData,plot=True)
# Out:
# c:\Users\01joh\OneDrive\Desktop\IoT\Prototyping\processClass.py:106: UserWarning: Optimal rotation is not uniquely or poorly defined for the given sets of vectors.
#   rotation = R.align_vectors([desired_orientation], [
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # For one sensors data
#       2 exerciseData = [pd.read_csv('t1.csv')]
# ----> 3 p.processSet(exerciseData,plot=True)
#
# File c:\Users\01joh\OneDrive\Desktop\IoT\Prototyping\processClass.py:637, in dataProcessor.processSet(self, exerciseData, plot)
#     634 stabilityScores = []
#     635 for rep in setData:
#     636     stabilityScores.append(
# --> 637         np.mean([self.calculateStabilityScore(phase) for phase in rep]))
#     638 setDetails['StabilityScores'].append(np.mean(stabilityScores))
#     640 # Force Calculations
#
# ...
